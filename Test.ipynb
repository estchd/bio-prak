# %%
from pathlib import Path

print(str(Path("data/regions/_3utr.bed").parent) + "/region")
# Out:
# data/regions/region

# %%
from src.files.files import Files

all_files = Files("data")

files = all_files.get_assembled_region_files()

with files.get_3utr_file().open_or_recompute() as _3utrFile:
    print("3utr open")
    for line in _3utrFile:
        print(line)
        break

with files.get_5utr_file().open_or_recompute() as _5utrFile:
    print("5utr open")
    for line in _5utrFile:
        print(line)
        break

with files.get_5utr_start_file().open_or_recompute() as _5utrStartFile:
    print("5utr start open")
    for line in _5utrStartFile:
        print(line)
        break

with files.get_cds_file().open_or_recompute() as cdsFile:
    print("cds open")
    for line in cdsFile:
        print(line)
        break

with files.get_coding_exons_file().open_or_recompute() as codingExonsFile:
    print("coding exons open")
    for line in codingExonsFile:
        print(line)
        break

with files.get_coding_introns_file().open_or_recompute() as codingIntronsFile:
    print("coding introns open")
    for line in codingIntronsFile:
        print(line)
        break

with files.get_exons_file().open_or_recompute() as exonsFile:
    print("exons open")
    for line in exonsFile:
        print(line)
        break

with files.get_introns_file().open_or_recompute() as intronsFile:
    print("introns open")
    for line in intronsFile:
        print(line)
        break

with files.get_non_coding_exons_file().open_or_recompute() as nonCodingExonsFile:
    print("non coding exons open")
    for line in nonCodingExonsFile:
        print(line)
        break
        
with files.get_non_coding_introns_file().open_or_recompute() as nonCodingIntronsFile:
    print("non coding introns open")
    for line in nonCodingIntronsFile:
        print(line)
        break
        
print("Done")
# Out:
# 3utr open
# chr8	166085	166088	NM_001005504.1_3utr	0	-	166085	166088	0	1	3,	0,
#
# 5utr open
# chr8	232136	240895	NM_001287255.1_5utr	0	+	232136	240895	0	2	131,72,	0,8687,
#
# 5utr start open
# chr8	232136	242901	NM_001287255.1_5utr_start	0	+	232136	242901	0	4	131,72,12,15,	0,8687,8759,10750,
#
# cds open
# chr8	166088	167024	NM_001005504.1_cds	0	-	166088	167024	0	1	936,	0,
#
# coding exons open
# chr8	166085	167024	NM_001005504.1_exon	0	-	166085	167024	0	1	939,	0,
#
# coding introns open
# chr8	232267	245153	NM_001287255.1_intron	0	+	232267	245153	0	5	8556,1979,708,813,452,	0,8640,10746,11538,12434,
#
# exons open
# chr8	63712	113102	NR_168395.1_exon	0	-	63712	113102	0	8	463,49,906,135,128,180,102,325,	0,556,6713,8080,15586,22688,29384,49065,
#
# introns open
# chr8	64175	112777	NR_168395.1_intron	0	-	64175	112777	0	7	93,6108,461,7371,6974,6516,19579,	0,142,7156,7752,15251,22405,29023,
#
# non coding exons open
# chr8	63712	113102	NR_168395.1_exon	0	-	63712	113102	0	8	463,49,906,135,128,180,102,325,	0,556,6713,8080,15586,22688,29384,49065,
#
# non coding introns open
# chr8	64175	112777	NR_168395.1_intron	0	-	64175	112777	0	7	93,6108,461,7371,6974,6516,19579,	0,142,7156,7752,15251,22405,29023,
#
# Done
