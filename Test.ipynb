# %%
from pathlib import Path

print(str(Path("data/regions/_3utr.bed").parent) + "/region")
# Out:
# data/regions/region

# %%
from src.files.files import get_files

files = get_files().get_assembled_region_local_intersects_assembled_files()

with files.get_3utr_file().open_or_recompute() as _3utrFile:
    print("3utr open")
    for line in _3utrFile:
        print(line)
        break

with files.get_5utr_file().open_or_recompute() as _5utrFile:
    print("5utr open")
    for line in _5utrFile:
        print(line)
        break

with files.get_5utr_start_file().open_or_recompute() as _5utrStartFile:
    print("5utr start open")
    for line in _5utrStartFile:
        print(line)
        break

with files.get_cds_file().open_or_recompute() as cdsFile:
    print("cds open")
    for line in cdsFile:
        print(line)
        break

with files.get_coding_exons_file().open_or_recompute() as codingExonsFile:
    print("coding exons open")
    for line in codingExonsFile:
        print(line)
        break

with files.get_coding_introns_file().open_or_recompute() as codingIntronsFile:
    print("coding introns open")
    for line in codingIntronsFile:
        print(line)
        break

with files.get_exons_file().open_or_recompute() as exonsFile:
    print("exons open")
    for line in exonsFile:
        print(line)
        break

with files.get_introns_file().open_or_recompute() as intronsFile:
    print("introns open")
    for line in intronsFile:
        print(line)
        break

with files.get_non_coding_exons_file().open_or_recompute() as nonCodingExonsFile:
    print("non coding exons open")
    for line in nonCodingExonsFile:
        print(line)
        break
        
with files.get_non_coding_introns_file().open_or_recompute() as nonCodingIntronsFile:
    print("non coding introns open")
    for line in nonCodingIntronsFile:
        print(line)
        break
        
print("Done")
# Out:
# Assembling local Intersects for data/regions_intersect_local/region_3utr_intersect_local.gz into data/regions_intersect_local_assembled/region_3utr_intersect_local_assembled.gz
# Assembling local Intersects for data/regions_intersect_local/region_3utr_intersect_local.gz into data/regions_intersect_local_assembled/region_3utr_intersect_local_assembled.gz done
# 3utr open
# NM_175075.5_3utr	127,150,180,252,1366,2017
#
# Assembling local Intersects for data/regions_intersect_local/region_5utr_intersect_local.gz into data/regions_intersect_local_assembled/region_5utr_intersect_local_assembled.gz
# Assembling local Intersects for data/regions_intersect_local/region_5utr_intersect_local.gz into data/regions_intersect_local_assembled/region_5utr_intersect_local_assembled.gz done
# 5utr open
# XM_047421403.1_5utr	24
#
# ...

# %%
from mypython.algorithms import accessibility

acc = accessibility("AGAC")
print(acc)
# Out:
# {30: {1: [], 2: [], 4: [], 8: []}}
